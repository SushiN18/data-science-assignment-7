# %% [markdown]
# # Using Normalize Function

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np
import scipy.stats as stats
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
airline=pd.read_excel("C:/Users/Sushi/Downloads/EastWestAirlines.xlsx")
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
airline.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
airline.shape
# Out:
# (3999, 12)

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline.isnull().values.any()
# Out:
# False

# %%
airline.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
airline2=airline.drop(['ID#'],axis=1)

# %%
airline.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
airline_norm = norm_func(airline2.iloc[:])

# %%
airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # Conducting Hierarical Clustering

# %%
import scipy.cluster.hierarchy as sch
from matplotlib import pyplot as plt

# %%
from sklearn.cluster import AgglomerativeClustering
hclusters=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='single')
hclusters
# Out:
# AgglomerativeClustering(linkage='single', n_clusters=5)

# %%
AgglomerativeClustering=hclusters.fit_predict(airline_norm)
AgglomerativeClustering
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
cluster_data=pd.DataFrame(AgglomerativeClustering, columns=['cluster'])
cluster_data
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 3994        1
# 3995        1
# 3996        1
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
airline_norm['clusters']=cluster_data
airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['clusters']==0]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0        0.0        0.0        0.0     0.000660
# 1     0.011288         0.0        0.0        0.0        0.0     0.000815
# 2     0.024257         0.0        0.0        0.0        0.0     0.015636
# 3     0.008667         0.0        0.0        0.0        0.0     0.001896
# 5     0.009631         0.0        0.0        0.0        0.0     0.000000
# ...        ...         ...        ...        ...        ...          ...
# 3991  0.022959         0.0        0.5        0.0        0.0     0.056814
# 3992  0.006558         0.0        0.0        0.0        0.0     0.003523
# 3993  0.002331         0.0        0.0        0.0        0.0     0.001384
# 3997  0.032202         0.0        0.0        0.0        0.0     0.001896
# 3998  0.001769         0.0        0.0        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # In the clustering 0 there are 3954 rows are grouped as 0 Cluster

# %%
airline_norm[airline_norm['clusters']==1]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# 7     0.012233         0.0       0.00        0.0        0.0     0.019910
# 8     0.259850         0.0       0.50        0.5        0.0     0.006648
# 9     0.061507         0.0       0.50        0.0        0.0     0.107803
# 11    0.056617         0.0       1.00        0.0        0.0     0.231735
# ...        ...         ...        ...        ...        ...          ...
# 3987  0.006999         0.0       0.00        0.0        0.0     0.000944
# 3989  0.001538         0.0       0.00        0.0        0.0     0.006163
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # in the cluster 1 there 1478 cluster arse segregated as 1 cluster

# %%
airline_norm[airline_norm['clusters']==2]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3583  0.093917    0.044851        0.0        0.0        0.0     0.272879
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3583          1.0                1.0              1.0             0.1653
#
#       Award?  clusters
# 3583     1.0         2

# %% [markdown]
# # there are only data points which is on cluster 2

# %%
airline_norm[airline_norm['clusters']==3]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 2840  0.005019         0.0        0.0        0.0        0.0      0.76084
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 2840      0.05814           0.020184         0.056604           0.235471
#
#       Award?  clusters
# 2840     1.0         3

# %% [markdown]
# # there are only data points which is on 3

# %%
airline_norm[airline_norm['clusters']==4]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 904  0.009288         0.0       0.25        0.0        1.0     0.425398
#
#      Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 904     0.186047                0.0              0.0           0.702074
#
#      Award?  clusters
# 904     1.0         4

# %% [markdown]
# # there are only data points which is on 4

# %%
airline_norm[airline_norm['clusters']==5]
# Out:
# Empty DataFrame
# Columns: [Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?, clusters]
# Index: []

# %% [markdown]
# # there are no clusters in 5
#
# # checking clustering performance with dendrogram

# %%
dendrogram=sch.dendrogram(sch.linkage(airline_norm,method='single'))

# %%
airline_norm.head()

# %%
del airline_norm['clusters']

# %%
airline_norm

# %%
from matplotlib import pyplot as plt
from sklearn .cluster import KMeans

# %%
wcss=[]

for i in range (1,10):
    kmeans= KMeans(n_clusters=i)
    kmeans.fit(airline_norm)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [1830.7932128584155,
#  823.6756984125224,
#  625.1684881570746,
#  436.70885761932635,
#  348.9433217254146,
#  315.15154060074144,
#  287.8950613257915,
#  263.05146938303017,
#  251.94259468721515]

# %% [markdown]
# # finding elbow method

# %%
plt.plot (range(1,10),wcss)
plt.show()

# %%
x=KMeans(n_clusters=4,max_iter=500,algorithm='auto')
x.fit(airline_norm)
# Out:
# KMeans(max_iter=500, n_clusters=4)

# %%
k_cluster=x.fit_predict(airline_norm)
k_cluster
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
airline_norm['k_clusters']=k_cluster
airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['k_clusters']==0]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# 8     0.259850         0.0       0.50        0.5        0.0     0.006648
# 9     0.061507         0.0       0.50        0.0        0.0     0.107803
# 11    0.056617         0.0       1.00        0.0        0.0     0.231735
# 15    0.016714         0.0       0.75        0.0        0.0     0.187504
# ...        ...         ...        ...        ...        ...          ...
# 3931  0.029046         0.0       0.50        0.0        0.0     0.097700
# 3954  0.019927         0.0       0.50        0.0        0.0     0.079750
# 3973  0.042407         0.0       0.50        0.0        0.0     0.061592
# 3979  0.033899         0.0       0.50        0.0        0.0     0.079485
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['k_clusters']==1]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0        0.0        0.0        0.0     0.000660
# 1     0.011288         0.0        0.0        0.0        0.0     0.000815
# 2     0.024257         0.0        0.0        0.0        0.0     0.015636
# 3     0.008667         0.0        0.0        0.0        0.0     0.001896
# 5     0.009631         0.0        0.0        0.0        0.0     0.000000
# ...        ...         ...        ...        ...        ...          ...
# 3990  0.006634         0.0        0.0        0.0        0.0     0.019042
# 3992  0.006558         0.0        0.0        0.0        0.0     0.003523
# 3993  0.002331         0.0        0.0        0.0        0.0     0.001384
# 3997  0.032202         0.0        0.0        0.0        0.0     0.001896
# 3998  0.001769         0.0        0.0        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['k_clusters']==2]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 7     0.012233    0.000000       0.00        0.0        0.0     0.019910
# 17    0.008187    0.000000       0.00        0.0        0.0     0.016273
# 21    0.108914    0.181557       0.00        0.0        0.0     0.050439
# 29    0.011274    0.000000       0.00        0.0        0.0     0.017654
# 36    0.013604    0.000000       0.00        0.0        0.0     0.002465
# ...        ...         ...        ...        ...        ...          ...
# 3978  0.005907    0.000000       0.25        0.0        0.0     0.105053
# 3987  0.006999    0.000000       0.00        0.0        0.0     0.000944
# 3989  0.001538    0.000000       0.00        0.0        0.0     0.006163
# 3994  0.010837    0.000000       0.00        0.0        0.0     0.032330
# 3995  0.037766    0.000000       0.00        0.0        0.0     0.003720
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['k_clusters']==3]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 6     0.049808         0.0       0.50        0.0        0.0     0.104223
# 30    0.104365         0.0       0.50        0.0        0.0     0.078871
# 32    0.162227         0.0       0.75        0.0        0.0     0.159448
# 44    0.071127         0.0       0.50        0.0        0.0     0.070133
# 56    0.044562         0.0       0.75        0.0        0.0     0.130227
# ...        ...         ...        ...        ...        ...          ...
# 3966  0.053732         0.0       0.75        0.0        0.0     0.143505
# 3974  0.034248         0.0       0.50        0.0        0.0     0.055297
# 3980  0.016932         0.0       0.50        0.0        0.0     0.072697
# 3985  0.034617         0.0       0.75        0.0        0.0     0.131771
# 3991  0.022959         0.0       0.50        0.0        0.0     0.056814
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # performing dbscan clustering

# %%
airline_norm.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0     0.011628           0.000000         0.000000           0.843742     0.0
# 1     0.023256           0.000000         0.000000           0.839884     0.0
# 2     0.046512           0.000000         0.000000           0.847842     0.0
# 3     0.011628           0.000000         0.000000           0.837955     0.0
# 4     0.302326           0.067398         0.075472           0.835905     1.0
#
#    k_clusters
# 0           1
# 1           1
# 2           1
# ...

# %%
del airline_norm['k_clusters']

# %%
airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from sklearn.cluster import DBSCAN

# %%
dbs=DBSCAN (min_samples=2,eps=0.2)

# %%
dbs_clusters=dbs.fit_predict(airline_norm)
dbs_clusters
# Out:
# array([0, 0, 0, ..., 4, 0, 0], dtype=int64)

# %%
airline_norm['dbs_clusters']=dbs_clusters

# %%
airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['dbs_clusters']==0]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0        0.0        0.0        0.0     0.000660
# 1     0.011288         0.0        0.0        0.0        0.0     0.000815
# 2     0.024257         0.0        0.0        0.0        0.0     0.015636
# 3     0.008667         0.0        0.0        0.0        0.0     0.001896
# 5     0.009631         0.0        0.0        0.0        0.0     0.000000
# ...        ...         ...        ...        ...        ...          ...
# 3990  0.006634         0.0        0.0        0.0        0.0     0.019042
# 3992  0.006558         0.0        0.0        0.0        0.0     0.003523
# 3993  0.002331         0.0        0.0        0.0        0.0     0.001384
# 3997  0.032202         0.0        0.0        0.0        0.0     0.001896
# 3998  0.001769         0.0        0.0        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['dbs_clusters']==1]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4     0.057338    0.000000       0.75        0.0        0.0     0.164211
# 15    0.016714    0.000000       0.75        0.0        0.0     0.187504
# 16    0.030437    0.000000       0.75        0.0        0.0     0.185687
# 35    0.072593    0.000000       0.75        0.0        0.0     0.191789
# 41    0.006141    0.000000       0.75        0.0        0.0     0.144468
# ...        ...         ...        ...        ...        ...          ...
# 3796  0.042414    0.000000       0.75        0.0        0.0     0.159088
# 3819  0.012301    0.133656       0.75        0.0        0.0     0.165072
# 3881  0.019019    0.000000       0.75        0.0        0.0     0.150312
# 3908  0.033811    0.000000       0.75        0.0        0.0     0.197872
# 3930  0.023711    0.000000       0.75        0.0        0.0     0.167283
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['dbs_clusters']==2]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 6     0.049808         0.0        0.5        0.0        0.0     0.104223
# 30    0.104365         0.0        0.5        0.0        0.0     0.078871
# 44    0.071127         0.0        0.5        0.0        0.0     0.070133
# 58    0.022335         0.0        0.5        0.0        0.0     0.129033
# 60    0.078868         0.0        0.5        0.0        0.0     0.059116
# ...        ...         ...        ...        ...        ...          ...
# 3946  0.081551         0.0        0.5        0.0        0.0     0.074198
# 3948  0.020828         0.0        0.5        0.0        0.0     0.053867
# 3974  0.034248         0.0        0.5        0.0        0.0     0.055297
# 3980  0.016932         0.0        0.5        0.0        0.0     0.072697
# 3991  0.022959         0.0        0.5        0.0        0.0     0.056814
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_norm[airline_norm['dbs_clusters']==3]
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 7     0.012233    0.000000        0.0        0.0        0.0     0.019910
# 17    0.008187    0.000000        0.0        0.0        0.0     0.016273
# 21    0.108914    0.181557        0.0        0.0        0.0     0.050439
# 29    0.011274    0.000000        0.0        0.0        0.0     0.017654
# 36    0.013604    0.000000        0.0        0.0        0.0     0.002465
# ...        ...         ...        ...        ...        ...          ...
# 3953  0.035151    0.066290        0.0        0.0        0.0     0.011756
# 3987  0.006999    0.000000        0.0        0.0        0.0     0.000944
# 3989  0.001538    0.000000        0.0        0.0        0.0     0.006163
# 3994  0.010837    0.000000        0.0        0.0        0.0     0.032330
# 3995  0.037766    0.000000        0.0        0.0        0.0     0.003720
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # Hence hirarical clusters has more than k means ans dbscan
